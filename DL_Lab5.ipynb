# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split

# %%
texts = [
    "I love this product",
    "This is a bad movie",
    "Excellent book",
    "Worst experience ever",
    "I feel great",
    "I hate it",
    "I hate this movie but ending is good",  # mixed sentiment
    "The movie was boring but visuals were amazing"
]

labels = [1, 0, 1, 0, 1, 0, 1, 1]  # 1 = positive, 0 = negative

# %%
max_words = 1000
max_len = 15

tokenizer = Tokenizer(num_words=max_words, oov_token="<OOV>")
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)
padded_sequences = pad_sequences(sequences, maxlen=max_len, padding='post')

print("Example padded sequence:\n", padded_sequences[6])
# Out:
# Example padded sequence:
#  [ 2  6  3  4  7 20  5 21  0  0  0  0  0  0  0]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    padded_sequences, labels, test_size=0.25, random_state=42
)

# %%
embedding_dim = 50

lstm_model = Sequential([
    Embedding(input_dim=max_words, output_dim=embedding_dim, input_length=max_len),
    LSTM(64),
    Dropout(0.5),
    Dense(1, activation='sigmoid')  # binary classification
])

lstm_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
lstm_model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
lstm_history = lstm_model.fit(
    X_train, np.array(y_train),
    epochs=20,
    batch_size=2,
    validation_data=(X_test, np.array(y_test))
)
# Out:
# Epoch 1/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.8333 - loss: 0.6857 - val_accuracy: 0.0000e+00 - val_loss: 0.7512
# Epoch 2/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8333 - loss: 0.6475 - val_accuracy: 0.0000e+00 - val_loss: 0.7855
# Epoch 3/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.8333 - loss: 0.6335 - val_accuracy: 0.0000e+00 - val_loss: 0.8492
# Epoch 4/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8333 - loss: 0.5758 - val_accuracy: 0.0000e+00 - val_loss: 0.9206
# Epoch 5/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8333 - loss: 0.5629 - val_accuracy: 0.0000e+00 - val_loss: 1.0276
# Epoch 6/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8333 - loss: 0.5661 - val_accuracy: 0.0000e+00 - val_loss: 1.1841
# Epoch 7/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8333 - loss: 0.4692 - val_accuracy: 0.0000e+00 - val_loss: 1.3562
# Epoch 8/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8333 - loss: 0.4555 - val_accuracy: 0.0000e+00 - val_loss: 1.6406
# Epoch 9/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8333 - loss: 0.4966 - val_accuracy: 0.0000e+00 - val_loss: 1.8558
# Epoch 10/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8333 - loss: 0.4282 - val_accuracy: 0.0000e+00 - val_loss: 1.9472
# Epoch 11/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8333 - loss: 0.4200 - val_accuracy: 0.0000e+00 - val_loss: 2.0076
# Epoch 12/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8333 - loss: 0.4075 - val_accuracy: 0.0000e+00 - val_loss: 2.1908
# Epoch 13/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8333 - loss: 0.5309 - val_accuracy: 0.0000e+00 - val_loss: 2.0910
# Epoch 14/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8333 - loss: 0.4397 - val_accuracy: 0.0000e+00 - val_loss: 1.9987
# Epoch 15/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8333 - loss: 0.4365 - val_accuracy: 0.0000e+00 - val_loss: 2.0150
# Epoch 16/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8333 - loss: 0.4881 - val_accuracy: 0.0000e+00 - val_loss: 1.9324
# Epoch 17/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8333 - loss: 0.4064 - val_accuracy: 0.0000e+00 - val_loss: 1.8828
# Epoch 18/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8333 - loss: 0.4308 - val_accuracy: 0.0000e+00 - val_loss: 1.8978
# Epoch 19/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8333 - loss: 0.3367 - val_accuracy: 0.0000e+00 - val_loss: 1.8906
# Epoch 20/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8333 - loss: 0.4236 - val_accuracy: 0.0000e+00 - val_loss: 1.8985

# %%
loss, accuracy = lstm_model.evaluate(X_test, np.array(y_test))
#print(f"Test Accuracy: {accuracy*100:.2f}%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - accuracy: 0.0000e+00 - loss: 1.8985

# %%
new_texts = [
    "I hate this movie but the ending is good",
    "Absolutely loved the story and characters"
]

seq = tokenizer.texts_to_sequences(new_texts)
padded_seq = pad_sequences(seq, maxlen=max_len, padding='post')
predictions = lstm_model.predict(padded_seq)

for text, pred in zip(new_texts, predictions):
    sentiment = "Positive" if pred[0] > 0.5 else "Negative"
    print(f"Text: {text}\nPredicted sentiment: {sentiment}\n")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# Text: I hate this movie but the ending is good
# Predicted sentiment: Positive
#
# Text: Absolutely loved the story and characters
# Predicted sentiment: Positive
